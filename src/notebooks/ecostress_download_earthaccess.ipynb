# %%
"""
ECOSTRESS Daily Evapotranspiration (ET) Download for Iowa (2019-2023)

This notebook downloads ECOSTRESS L3 JET (Evapotranspiration) data for Iowa
using NASA's earthaccess library.

PURPOSE:
--------
Download ECOSTRESS actual ET observations to combine with NLDAS modeled ET
for irrigation detection using the Pierrat et al. (2025) Human ET methodology:
    Human ET = ECOSTRESS ET - NLDAS ET_baseline
    
Where ECOSTRESS ET > NLDAS ET, the excess represents human water inputs
(irrigation) beyond natural water availability.

Dataset: ECOSTRESS Evapotranspiration PT-JPL L3 Daily 70 m V002
Short Name: ECO_L3T_JET
DOI: 10.5067/ECOSTRESS/ECO_L3T_JET.002
Key Variable: ETdaily (Daily integrated evapotranspiration)
Units: kg/m2/day (equivalent to mm/day)
Spatial Resolution: ~70 m

ECOSTRESS Characteristics:
- Irregular temporal sampling (not daily global coverage)
- Multiple overpass times capture diurnal variation
- Higher spatial resolution (~70m) than NLDAS (~12km)
- Cloud masking required

Requirements:
- earthaccess library
- NASA Earthdata account (~/.netrc)

Adapted for SIF-ET-Irrigation Analysis Project - Iowa 2019-2023
Following methodology from Pierrat et al. (2025)
"""

# %%
import os
from pathlib import Path

# Check if /work exists and is writable
work_dir = Path("/work/jcoldiron")
home_dir = Path("/home/jcoldiron/iowa-corn-project")

print("Checking /work directory:")
print(f"  Exists: {work_dir.exists()}")
if work_dir.exists():
    print(f"  Writable: {os.access(work_dir, os.W_OK)}")
    
print("\nChecking home project directory:")
print(f"  Exists: {home_dir.exists()}")
print(f"  Writable: {os.access(home_dir, os.W_OK)}")

# Also check for the Python script
script_path = Path("/home/jcoldiron/iowa-corn-project/code/SIF-Analysis/src/scripts/ecostress_monthly.py")
print(f"\nChecking for ecostress_monthly.py:")
print(f"  Exists: {script_path.exists()}")
if script_path.exists():
    print(f"  Location: {script_path}")
# Out:
# Checking /work directory:
#   Exists: False
#
# Checking home project directory:
#   Exists: True
#   Writable: True
#
# Checking for ecostress_monthly.py:
#   Exists: True
#   Location: /home/jcoldiron/iowa-corn-project/code/SIF-Analysis/src/scripts/ecostress_monthly.py

# %%
# Check what your ecostress_monthly.py does
script_path = Path("/home/jcoldiron/iowa-corn-project/code/SIF-Analysis/src/scripts/ecostress_monthly.py")

print("First 50 lines of ecostress_monthly.py:")
print("="*60)
with open(script_path) as f:
    for i, line in enumerate(f, 1):
        if i <= 50:
            print(f"{i:3}: {line}", end="")
        else:
            break
# Out:
# First 50 lines of ecostress_monthly.py:
# ============================================================
#   1: #!/usr/bin/env python3
#   2: """
#   3: ECOSTRESS Data Download for Iowa (2019-2023)
#   4: Runs as batch job on GRIT HPC
#   5:
#   6: Downloads ECOSTRESS L3 JET evapotranspiration data to:
#   7: /work/jcoldiron/data/raw/ECOSTRESS_JET/
#   8:
#   9: Logs progress to stdout for SLURM capture.
#  10: """
#  11:
#  12: import sys
#  13: import subprocess
#  14: from pathlib import Path
#  15: from datetime import datetime
#  16:
#  17: # =============================================================================
#  18: # Install earthaccess if needed
#  19: # =============================================================================
#  20: print("Setting up earthaccess...", flush=True)
#  21:
#  22: target_dir = '/home/jcoldiron/.local/lib/python3.12/site-packages'
#  23:
#  24: # Try to import, install if missing
#  25: try:
#  26:     if target_dir not in sys.path:
#  27:         sys.path.insert(0, target_dir)
#  28:     import earthaccess
#  29:     print(f"earthaccess version: {earthaccess.__version__}", flush=True)
#  30: except ImportError:
#  31:     print("earthaccess not found, installing...", flush=True)
#  32:     subprocess.check_call([
#  33:         sys.executable, '-m', 'pip', 'install',
#  34:         '--target=' + target_dir,
#  35:         'earthaccess'
#  36:     ])
#  37:     if target_dir not in sys.path:
#  38:         sys.path.insert(0, target_dir)
#  39:     import earthaccess
#  40:     print(f"Installed earthaccess version: {earthaccess.__version__}", flush=True)
#  41:
#  42: # =============================================================================
#  43: # Configuration
#  44: # =============================================================================
#  45:
#  46: # Temporal range
#  47: START_YEAR = 2019
#  48: END_YEAR = 2023
#  49: temporal_range = (f"{START_YEAR}-01-01", f"{END_YEAR}-12-31")
#  50:

# %%
import sys
import subprocess

# Install to your home directory
target_dir = '/home/jcoldiron/.local/lib/python3.12/site-packages'
subprocess.check_call([
    sys.executable, '-m', 'pip', 'install', 
    '--target=' + target_dir,
    'earthaccess'
])

# Add to Python path
if target_dir not in sys.path:
    sys.path.insert(0, target_dir)

print(f"Installed to: {target_dir}")
print("Now try: import earthaccess")

# Install earthaccess if needed
# pip install earthaccess

import earthaccess
print(f"earthaccess version: {earthaccess.__version__}")
# Out:
# Collecting earthaccess
#   Using cached earthaccess-0.16.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting fsspec>=2025.2 (from earthaccess)
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting importlib-resources>=6.3.2 (from earthaccess)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting multimethod>=1.8 (from earthaccess)
#   Using cached multimethod-2.0.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting pqdm>=0.1 (from earthaccess)
#   Using cached pqdm-0.2.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting python-cmr>=0.10.0 (from earthaccess)
#   Using cached python_cmr-0.13.0-py3-none-any.whl.metadata (10 kB)
# Collecting requests>=2.26 (from earthaccess)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting s3fs>=2025.2 (from earthaccess)
#   Using cached s3fs-2026.2.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tenacity>=8.0 (from earthaccess)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting tinynetrc>=1.3.1 (from earthaccess)
#   Using cached tinynetrc-1.3.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from earthaccess)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting bounded-pool-executor (from pqdm>=0.1->earthaccess)
#   Using cached bounded_pool_executor-0.0.3-py3-none-any.whl.metadata (2.7 kB)
# Collecting tqdm (from pqdm>=0.1->earthaccess)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting python-dateutil<3.0.0,>=2.8.2 (from python-cmr>=0.10.0->earthaccess)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.26->earthaccess)
#   Using cached charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests>=2.26->earthaccess)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.26->earthaccess)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.26->earthaccess)
#   Using cached certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Collecting aiobotocore<4.0.0,>=2.19.0 (from s3fs>=2025.2->earthaccess)
#   Using cached aiobotocore-3.1.2-py3-none-any.whl.metadata (26 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from s3fs>=2025.2->earthaccess)
#   Using cached aiohttp-3.13.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<4.0.0,>=2.19.0->s3fs>=2025.2->earthaccess)
#   Using cached aioitertools-0.13.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting botocore<1.42.43,>=1.41.0 (from aiobotocore<4.0.0,>=2.19.0->s3fs>=2025.2->earthaccess)
#   Using cached botocore-1.42.42-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<4.0.0,>=2.19.0->s3fs>=2025.2->earthaccess)
#   Using cached jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting multidict<7.0.0,>=6.0.0 (from aiobotocore<4.0.0,>=2.19.0->s3fs>=2025.2->earthaccess)
#   Using cached multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting wrapt<3.0.0,>=1.10.10 (from aiobotocore<4.0.0,>=2.19.0->s3fs>=2025.2->earthaccess)
#   Using cached wrapt-2.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Using cached frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Using cached propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Using cached yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Collecting six>=1.5 (from python-dateutil<3.0.0,>=2.8.2->python-cmr>=0.10.0->earthaccess)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached earthaccess-0.16.0-py3-none-any.whl (71 kB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached multimethod-2.0.2-py3-none-any.whl (9.6 kB)
# Using cached pqdm-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Using cached python_cmr-0.13.0-py3-none-any.whl (14 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached s3fs-2026.2.0-py3-none-any.whl (31 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached tinynetrc-1.3.1-py2.py3-none-any.whl (3.9 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached aiobotocore-3.1.2-py3-none-any.whl (87 kB)
# Using cached aiohttp-3.13.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
# Using cached certifi-2026.1.4-py3-none-any.whl (152 kB)
# Using cached charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached bounded_pool_executor-0.0.3-py3-none-any.whl (3.4 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aioitertools-0.13.0-py3-none-any.whl (24 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Using cached botocore-1.42.42-py3-none-any.whl (14.6 MB)
# Using cached frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
# Using cached jmespath-1.1.0-py3-none-any.whl (20 kB)
# Using cached multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
# Using cached propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (221 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached wrapt-2.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (121 kB)
# Using cached yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (377 kB)
# Installing collected packages: tinynetrc, bounded-pool-executor, wrapt, urllib3, typing-extensions, tqdm, tenacity, six, propcache, multimethod, multidict, jmespath, importlib-resources, idna, fsspec, frozenlist, charset_normalizer, certifi, attrs, aioitertools, aiohappyeyeballs, yarl, requests, python-dateutil, pqdm, aiosignal, python-cmr, botocore, aiohttp, aiobotocore, s3fs, earthaccess
# Successfully installed aiobotocore-3.1.2 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aioitertools-0.13.0 aiosignal-1.4.0 attrs-25.4.0 botocore-1.42.42 bounded-pool-executor-0.0.3 certifi-2026.1.4 charset_normalizer-3.4.4 earthaccess-0.16.0 frozenlist-1.8.0 fsspec-2026.2.0 idna-3.11 importlib-resources-6.5.2 jmespath-1.1.0 multidict-6.7.1 multimethod-2.0.2 pqdm-0.2.0 propcache-0.4.1 python-cmr-0.13.0 python-dateutil-2.9.0.post0 requests-2.32.5 s3fs-2026.2.0 six-1.17.0 tenacity-9.1.4 tinynetrc-1.3.1 tqdm-4.67.3 typing-extensions-4.15.0 urllib3-2.6.3 wrapt-2.1.1 yarl-1.22.0
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/fsspec-2026.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/importlib_resources already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/six-1.17.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/aiohttp-3.13.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/aiobotocore-3.1.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/aioitertools already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/bounded_pool_executor-0.0.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/earthaccess already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/jmespath already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/frozenlist already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/certifi-2026.1.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/typing_extensions-4.15.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/multidict already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/earthaccess-0.16.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/multidict-6.7.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/attrs-25.4.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/jmespath-1.1.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/tinynetrc-1.3.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/idna-3.11.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/attrs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/fsspec already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/idna already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/s3fs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/dateutil already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/wrapt-2.1.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/urllib3 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/charset_normalizer-3.4.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/tqdm already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/multimethod already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/bounded_pool_executor already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/yarl-1.22.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/aiosignal-1.4.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/aiohttp already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/requests already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/pqdm already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/botocore-1.42.42.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/aiobotocore already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/s3fs-2026.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/python_cmr-0.13.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/frozenlist-1.8.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/tinynetrc.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/attr already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/tqdm-4.67.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/aioitertools-0.13.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/multimethod-2.0.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/charset_normalizer already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/aiohappyeyeballs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/tenacity already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/tenacity-9.1.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/wrapt already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/aiohappyeyeballs-2.6.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/aiosignal already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/certifi already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/urllib3-2.6.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/botocore already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/propcache already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/cmr already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/pqdm-0.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/typing_extensions.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/requests-2.32.5.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/python_dateutil-2.9.0.post0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/propcache-0.4.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/importlib_resources-6.5.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/yarl already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/jcoldiron/.local/lib/python3.12/site-packages/bin already exists. Specify --upgrade to force replacement.
# Installed to: /home/jcoldiron/.local/lib/python3.12/site-packages
# Now try: import earthaccess
# earthaccess version: 0.16.0

# %%
# Install earthaccess if needed
# pip install earthaccess rioxarray geopandas

import earthaccess
#import xarray as xr
#import rioxarray as rxr
#import geopandas as gpd
#import pandas as pd
from pathlib import Path
#import numpy as np
from datetime import datetime
#import matplotlib.pyplot as plt

print(f"earthaccess version: {earthaccess.__version__}")
# Out:
# earthaccess version: 0.16.0

# %%
# =============================================================================
# CONFIGURATION
# =============================================================================

# Authenticate with NASA Earthdata
auth = earthaccess.login()

# Temporal range - Full 5-year period
start_year = 2019
end_year = 2023
temporal_range = (f"{start_year}-01-01", f"{end_year}-12-31")

# Iowa bounding box (west, south, east, north)
iowa_bbox = (-96.64, 40.38, -90.14, 43.50)

# Project paths
project_root = Path("../..").resolve()
local_path = project_root / "data" / "raw" / "ECOSTRESS_JET"
local_path.mkdir(parents=True, exist_ok=True)

print(f"Project root: {project_root}")
print(f"Download path: {local_path}")
print(f"Temporal range: {temporal_range}")
print(f"Bounding box (Iowa): {iowa_bbox}")

# =============================================================================
# SEARCH ECOSTRESS DATA
# =============================================================================

print(f"\nSearching ECOSTRESS L3 JET data for Iowa {start_year}-{end_year}...")

results = earthaccess.search_data(
    short_name='ECO_L3T_JET',
    version='002',
    bounding_box=iowa_bbox,
    temporal=temporal_range
)

print(f"Found {len(results)} granules")
print(f"\nNote: ECOSTRESS has irregular temporal sampling.")
print(f"Each granule contains multiple files (ETdaily, ETinst, cloud masks, etc.)")

if results:
    # Show first result structure
    print(f"\nFirst granule info:")
    print(f"  Date: {results[0]['umm']['TemporalExtent']['RangeDateTime']['BeginningDateTime']}")
    print(f"  Files in granule: {len(results[0]['umm']['RelatedUrls'])}")
    
    # Count by year
    dates = [r['umm']['TemporalExtent']['RangeDateTime']['BeginningDateTime'] for r in results]
    years = [datetime.fromisoformat(d.replace('Z', '+00:00')).year for d in dates]
    year_counts = pd.Series(years).value_counts().sort_index()
    print(f"\nGranules per year:")
    for year, count in year_counts.items():
        print(f"  {year}: {count}")
# Out:
# Enter your Earthdata Login username:  jcoldiron
# Enter your Earthdata password:  ········
# Project root: /home/jcoldiron/iowa-corn-project/code/SIF-Analysis
# Download path: /home/jcoldiron/iowa-corn-project/code/SIF-Analysis/data/raw/ECOSTRESS_JET
# Temporal range: ('2019-01-01', '2023-12-31')
# Bounding box (Iowa): (-96.64, 40.38, -90.14, 43.5)
#
# Searching ECOSTRESS L3 JET data for Iowa 2019-2023...

# %%
# =============================================================================
# DOWNLOAD ECOSTRESS GRANULES
# =============================================================================

print(f"\nDownloading {len(results)} granules...")
print(f"This may take a while. Each granule has multiple files.")

downloaded_files = earthaccess.download(
    results, 
    local_path=str(local_path)
)

print(f"\nDownloaded {len(downloaded_files)} total files")
print(f"Location: {local_path}")

# Organize by file type
etdaily_files = [f for f in downloaded_files if 'ETdaily.tif' in str(f)]
cloud_files = [f for f in downloaded_files if 'cloud.tif' in str(f)]

print(f"\nFile breakdown:")
print(f"  ETdaily files: {len(etdaily_files)}")
print(f"  Cloud mask files: {len(cloud_files)}")
print(f"  Other files: {len(downloaded_files) - len(etdaily_files) - len(cloud_files)}")

# %%
"""
Process and Clip ECOSTRESS ET Data to Iowa Boundary

This cell:
1. Loads each ECOSTRESS ETdaily.tif file
2. Applies cloud mask
3. Clips to Iowa state boundary
4. Saves clipped files with metadata
5. Creates temporal summaries

ETdaily units: kg/m2/day (equivalent to mm/day)
Scale factor: 0.1 (stored as integers, multiply by 0.1 to get mm/day)
"""

# =============================================================================
# File Paths
# =============================================================================

input_folder = project_root / "data" / "raw" / "ECOSTRESS_JET"
output_folder = project_root / "data" / "processed" / "ECOSTRESS_Iowa"
output_folder.mkdir(parents=True, exist_ok=True)

iowa_boundary = project_root / "data" / "aoi" / "iowa.geojson"

# Load Iowa boundary
gdf = gpd.read_file(iowa_boundary)
print(f"Iowa boundary CRS: {gdf.crs}")

# Find all ETdaily files
etdaily_files = sorted(input_folder.glob("**/*ETdaily.tif"))
print(f"\nFound {len(etdaily_files)} ETdaily files to process")

# =============================================================================
# Process Each ECOSTRESS File
# =============================================================================

processed_count = 0
skipped_count = 0
metadata = []

for etdaily_file in etdaily_files:
    try:
        # Extract date from filename
        # Format: ECOv002_L3T_JET_28282_005_15TVH_20230702T130331_0712_01_ETdaily.tif
        filename = etdaily_file.stem
        parts = filename.split('_')
        date_str = parts[6]  # e.g., '20230702T130331'
        date = datetime.strptime(date_str[:8], '%Y%m%d')
        
        # Find corresponding cloud mask
        cloud_file = etdaily_file.parent / filename.replace('ETdaily', 'cloud').replace(etdaily_file.stem, filename.replace('ETdaily', 'cloud')) + '.tif'
        
        # Load ET data
        et_data = rxr.open_rasterio(etdaily_file, masked=True)
        
        # Apply scale factor (ECOSTRESS stores as integers, scale by 0.1)
        et_data = et_data * 0.1
        
        # Apply cloud mask if available
        if cloud_file.exists():
            cloud_mask = rxr.open_rasterio(cloud_file, masked=True)
            # Cloud mask: 0=cloud, 1=clear
            et_data = et_data.where(cloud_mask == 1)
        
        # Set CRS if not already set
        if et_data.rio.crs is None:
            et_data = et_data.rio.write_crs("EPSG:4326")
        
        # Clip to Iowa
        gdf_projected = gdf.to_crs(et_data.rio.crs)
        clipped = et_data.rio.clip(gdf_projected.geometry, gdf_projected.crs, drop=True)
        
        # Save clipped file
        output_filename = f"ECOSTRESS_ET_{date.strftime('%Y%m%d')}_Iowa.tif"
        output_path = output_folder / output_filename
        
        clipped.rio.to_raster(
            output_path,
            compress='lzw',
            tiled=True,
            dtype='float32'
        )
        
        # Store metadata
        metadata.append({
            'date': date,
            'filename': output_filename,
            'mean_et': float(clipped.mean()),
            'median_et': float(clipped.median()),
            'valid_pixels': int((~np.isnan(clipped.values[0])).sum())
        })
        
        processed_count += 1
        if processed_count % 50 == 0:
            print(f"Processed {processed_count}/{len(etdaily_files)} files...")
        
    except Exception as e:
        print(f"Error processing {etdaily_file.name}: {e}")
        skipped_count += 1
        continue

print(f"\nProcessing complete!")
print(f"  Processed: {processed_count}")
print(f"  Skipped: {skipped_count}")

# =============================================================================
# Save Metadata
# =============================================================================

if metadata:
    df = pd.DataFrame(metadata)
    df = df.sort_values('date')
    metadata_path = output_folder / "ECOSTRESS_Iowa_metadata.csv"
    df.to_csv(metadata_path, index=False)
    print(f"\nSaved metadata to: {metadata_path}")
    
    # Summary statistics
    print(f"\nTemporal coverage:")
    print(f"  First observation: {df['date'].min()}")
    print(f"  Last observation: {df['date'].max()}")
    print(f"  Total observations: {len(df)}")
    
    print(f"\nET statistics (mm/day):")
    print(f"  Mean: {df['mean_et'].mean():.2f}")
    print(f"  Median: {df['median_et'].median():.2f}")
    print(f"  Range: {df['mean_et'].min():.2f} - {df['mean_et'].max():.2f}")

# %%
"""
Visualize ECOSTRESS Temporal Coverage and ET Values
"""

if metadata:
    df = pd.DataFrame(metadata)
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values('date')
    
    fig, axes = plt.subplots(2, 1, figsize=(14, 10))
    
    # Plot 1: Temporal distribution of observations
    ax1 = axes[0]
    df_monthly = df.groupby(df['date'].dt.to_period('M')).size()
    df_monthly.plot(kind='bar', ax=ax1, color='steelblue')
    ax1.set_title('ECOSTRESS Observations per Month (Iowa, 2019-2023)', 
                  fontsize=14, fontweight='bold')
    ax1.set_xlabel('Month')
    ax1.set_ylabel('Number of Observations')
    ax1.grid(axis='y', alpha=0.3)
    
    # Plot 2: ET time series
    ax2 = axes[1]
    ax2.scatter(df['date'], df['mean_et'], alpha=0.5, s=20, color='darkgreen')
    ax2.set_title('ECOSTRESS Mean Daily ET - Iowa (2019-2023)', 
                  fontsize=14, fontweight='bold')
    ax2.set_xlabel('Date')
    ax2.set_ylabel('Mean ET (mm/day)')
    ax2.grid(True, alpha=0.3)
    
    # Add monthly average line
    df_monthly_et = df.groupby(df['date'].dt.to_period('M'))['mean_et'].mean()
    df_monthly_et.index = df_monthly_et.index.to_timestamp()
    ax2.plot(df_monthly_et.index, df_monthly_et.values, 
             color='red', linewidth=2, alpha=0.7, label='Monthly Average')
    ax2.legend()
    
    plt.tight_layout()
    plt.savefig(output_folder / "ECOSTRESS_temporal_coverage.png", dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f"\nNote: ECOSTRESS has irregular temporal sampling.")
    print(f"You'll need to aggregate these observations to bi-weekly periods")
    print(f"to match your project timeline and combine with NLDAS data.")

# %%
"""
Create Sample Visualization - Mean ET for Summer 2023
"""

if metadata:
    # Filter for summer months (June-August) 2023
    df = pd.DataFrame(metadata)
    df['date'] = pd.to_datetime(df['date'])
    
    summer_2023 = df[(df['date'].dt.year == 2023) & 
                     (df['date'].dt.month.isin([6, 7, 8]))]
    
    print(f"Found {len(summer_2023)} observations for Summer 2023")
    
    if len(summer_2023) > 0:
        # Load and average all summer 2023 files
        summer_files = [output_folder / f for f in summer_2023['filename']]
        
        et_arrays = []
        for file in summer_files:
            data = rxr.open_rasterio(file, masked=True)
            et_arrays.append(data)
        
        # Compute mean across all observations
        et_mean = xr.concat(et_arrays, dim='time').mean(dim='time', skipna=True)
        
        # Plot
        fig, ax = plt.subplots(figsize=(10, 8))
        et_mean.plot(
            ax=ax,
            cmap='YlGnBu',
            vmin=0,
            vmax=8,
            cbar_kwargs={'label': 'Mean ET (mm/day)'}
        )
        ax.set_title('ECOSTRESS Mean Daily ET - Iowa Summer 2023\n(June-August Average)',
                     fontsize=14, fontweight='bold')
        ax.set_xlabel('Longitude')
        ax.set_ylabel('Latitude')
        
        plt.tight_layout()
        plt.savefig(output_folder / "ECOSTRESS_summer2023_mean.png", dpi=300, bbox_inches='tight')
        plt.show()
        
        print(f"\nSummer 2023 mean ET: {float(et_mean.mean()):.2f} mm/day")

# %%
from pathlib import Path

print("Checking setup before submission...")
print("="*60)

# 1. Check ecostress_monthly.py has correct path
script_path = Path("/home/jcoldiron/iowa-corn-project/code/SIF-Analysis/src/scripts/ecostress_monthly.py")
with open(script_path) as f:
    content = f.read()
    
if "/work/jcoldiron" in content:
    print("❌ ERROR: ecostress_monthly.py still has /work/jcoldiron paths!")
    print("   Run the fix code cell above first!")
elif "/home/jcoldiron/iowa-corn-project" in content:
    print("✅ ecostress_monthly.py has correct paths")
else:
    print("⚠️  Warning: Could not verify paths")

# 2. Check batch script exists
batch_script = Path("/home/jcoldiron/iowa-corn-project/code/SIF-Analysis/src/scripts/submit_ecostress_download.sh")
print(f"✅ Batch script exists: {batch_script.exists()}")

# 3. Check .netrc exists
netrc = Path.home() / ".netrc"
print(f"✅ .netrc exists: {netrc.exists()}")

# 4. Check logs directory exists
logs_dir = Path("/home/jcoldiron/iowa-corn-project/logs")
logs_dir.mkdir(parents=True, exist_ok=True)
print(f"✅ Logs directory: {logs_dir}")

# 5. Check data directory exists
data_dir = Path("/home/jcoldiron/iowa-corn-project/data/raw/ECOSTRESS_JET")
data_dir.mkdir(parents=True, exist_ok=True)
print(f"✅ Data directory: {data_dir}")

print("="*60)
print("\nIf all checks pass, you're ready to submit!")
# Out:
# Checking setup before submission...
# ============================================================
# ❌ ERROR: ecostress_monthly.py still has /work/jcoldiron paths!
#    Run the fix code cell above first!
# ✅ Batch script exists: True
# ✅ .netrc exists: False
# ✅ Logs directory: /home/jcoldiron/iowa-corn-project/logs
# ✅ Data directory: /home/jcoldiron/iowa-corn-project/data/raw/ECOSTRESS_JET
# ============================================================
#
# If all checks pass, you're ready to submit!

# %%
from pathlib import Path

# Fix the paths in ecostress_monthly.py
script_path = Path("/home/jcoldiron/iowa-corn-project/code/SIF-Analysis/src/scripts/ecostress_monthly.py")

# Read current content
with open(script_path) as f:
    content = f.read()

# Replace all instances of /work/jcoldiron with correct path
content = content.replace(
    '/work/jcoldiron/data/raw/ECOSTRESS_JET',
    '/home/jcoldiron/iowa-corn-project/data/raw/ECOSTRESS_JET'
)

# Write back
with open(script_path, 'w') as f:
    f.write(content)

print("✅ Fixed paths in ecostress_monthly.py")

# Verify
with open(script_path) as f:
    new_content = f.read()
    
if "/work/jcoldiron" in new_content:
    print("❌ Still has /work paths - manual fix needed")
else:
    print("✅ Verified: No more /work paths")
# Out:
# ✅ Fixed paths in ecostress_monthly.py
# ❌ Still has /work paths - manual fix needed

# %%
from pathlib import Path

# Read the current file to see what's wrong
script_path = Path("/home/jcoldiron/iowa-corn-project/code/SIF-Analysis/src/scripts/ecostress_monthly.py")

with open(script_path) as f:
    lines = f.readlines()

# Find all lines with /work/jcoldiron
print("Lines still containing /work/jcoldiron:")
print("="*60)
for i, line in enumerate(lines, 1):
    if '/work/jcoldiron' in line:
        print(f"Line {i}: {line.rstrip()}")
# Out:
# Lines still containing /work/jcoldiron:
# ============================================================
# Line 173: if "/work/jcoldiron" in verify:
# Line 177:         if '/work/jcoldiron' in line:

# %%
from pathlib import Path

script_path = Path("/home/jcoldiron/iowa-corn-project/code/SIF-Analysis/src/scripts/ecostress_monthly.py")

# Read the actual script file
with open(script_path) as f:
    content = f.read()

# Check line 7 (the docstring) and line 56 (output_path)
lines = content.split('\n')

print("Checking key lines in ecostress_monthly.py:")
print("="*60)
print(f"Line 7 (docstring):  {lines[6]}")
print(f"Line 56 (output_path): {lines[55]}")
print("="*60)

if "/home/jcoldiron/iowa-corn-project" in lines[6] and "/home/jcoldiron/iowa-corn-project" in lines[55]:
    print("✅ Script file is CORRECT!")
elif "/work/jcoldiron" in content:
    print("❌ Script still has /work/jcoldiron paths")
else:
    print("⚠️ Paths look different than expected")
# Out:
# Checking key lines in ecostress_monthly.py:
# ============================================================
# Line 7 (docstring):  """
# Line 56 (output_path): # Iowa bounding box (west, south, east, north)
# ============================================================
# ❌ Script still has /work/jcoldiron paths

# %%
from pathlib import Path

script_path = Path("/home/jcoldiron/iowa-corn-project/code/SIF-Analysis/src/scripts/ecostress_monthly.py")

with open(script_path) as f:
    lines = f.readlines()

print("Searching for ALL lines with paths:")
print("="*60)
for i, line in enumerate(lines, 1):
    if '/work/jcoldiron' in line or 'output_path' in line or 'Downloads ECOSTRESS' in line:
        print(f"Line {i}: {line.rstrip()}")
print("="*60)
# Out:
# Searching for ALL lines with paths:
# ============================================================
# Line 11: Downloads ECOSTRESS L3 JET evapotranspiration data to:
# Line 60: output_path = Path("/home/jcoldiron/iowa-corn-project/data/raw/ECOSTRESS_JET")
# Line 61: output_path.mkdir(parents=True, exist_ok=True)
# Line 64: log_file = output_path / f"download_log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"
# Line 123: log(f"\\nStarting download to: {output_path}")
# Line 129:         local_path=str(output_path)
# Line 136:     log(f"Location: {output_path}")
# Line 149:     filelist_path = output_path / "downloaded_files.txt"
# Line 173: if "/work/jcoldiron" in verify:
# Line 177:         if '/work/jcoldiron' in line:
# ============================================================

# %%
from pathlib import Path

script_path = Path("/home/jcoldiron/iowa-corn-project/code/SIF-Analysis/src/scripts/ecostress_monthly.py")

with open(script_path) as f:
    lines = f.readlines()

# Show lines 11-13 (the docstring path)
print("Docstring path:")
for i in range(10, 13):
    print(f"Line {i+1}: {lines[i].rstrip()}")

print("\nOutput path line:")
print(f"Line 60: {lines[59].rstrip()}")

# Final check
content = ''.join(lines)
if "/work/jcoldiron" in content:
    print("\n❌ Script still has /work/jcoldiron")
else:
    print("\n✅ Script is CORRECT - no /work/jcoldiron paths!")
# Out:
# Docstring path:
# Line 11: Downloads ECOSTRESS L3 JET evapotranspiration data to:
# Line 12: /home/jcoldiron/iowa-corn-project/data/raw/ECOSTRESS_JET/
# Line 13:
#
# Output path line:
# Line 60: output_path = Path("/home/jcoldiron/iowa-corn-project/data/raw/ECOSTRESS_JET")
#
# ❌ Script still has /work/jcoldiron
