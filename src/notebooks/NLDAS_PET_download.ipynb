# %%
"""
NLDAS Potential Evaporation (PET) Download for Iowa (2023)

This notebook downloads NLDAS (North American Land Data Assimilation System) 
monthly potential evaporation data for Iowa using NASA's earthaccess library.

PURPOSE:
--------
Download PET to compare with ECOSTRESS actual ET:
    PET - ET = Irrigation signal (human-induced ET)

Where ET > PET, water inputs beyond atmospheric demand indicate irrigation.

Dataset: NLDAS Primary Forcing Data L4 Monthly 0.125 x 0.125 degree
DOI: 10.5067/2DPKB5B5N14O
Variable: PEVAP (Potential Evaporation)

Requirements:
- earthaccess library
- NASA Earthdata account

Adapted for SIF-ET-Irrigation Analysis Project - Iowa 2023
"""
# Out:
# "\nNLDAS Potential Evaporation (PET) Download for Iowa (2023)\n\nThis notebook downloads NLDAS (North American Land Data Assimilation System) \nmonthly potential evaporation data for Iowa using NASA's earthaccess library.\n\nPURPOSE:\n--------\nDownload PET to compare with ECOSTRESS actual ET:\n    PET - ET = Irrigation signal (human-induced ET)\n\nWhere ET > PET, water inputs beyond atmospheric demand indicate irrigation.\n\nDataset: NLDAS Primary Forcing Data L4 Monthly 0.125 x 0.125 degree\nDOI: 10.5067/2DPKB5B5N14O\nVariable: PEVAP (Potential Evaporation)\n\nRequirements:\n- earthaccess library\n- NASA Earthdata account\n\nAdapted for SIF-ET-Irrigation Analysis Project - Iowa 2023\n"

# %%
import sys
import subprocess

# Install to your home directory
target_dir = '/home/jcoldiron/.local/lib/python3.12/site-packages'
subprocess.check_call([
    sys.executable, '-m', 'pip', 'install', 
    '--target=' + target_dir,
    'earthaccess'
])

# Add to Python path
if target_dir not in sys.path:
    sys.path.insert(0, target_dir)

print(f"Installed to: {target_dir}")
print("Now try: import earthaccess")
# Out:
# Collecting earthaccess
#   Using cached earthaccess-0.16.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting fsspec>=2025.2 (from earthaccess)
#   Using cached fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting importlib-resources>=6.3.2 (from earthaccess)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting multimethod>=1.8 (from earthaccess)
#   Using cached multimethod-2.0.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting pqdm>=0.1 (from earthaccess)
#   Using cached pqdm-0.2.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting python-cmr>=0.10.0 (from earthaccess)
#   Using cached python_cmr-0.13.0-py3-none-any.whl.metadata (10 kB)
# Collecting requests>=2.26 (from earthaccess)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting s3fs>=2025.2 (from earthaccess)
#   Using cached s3fs-2026.1.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tenacity>=8.0 (from earthaccess)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting tinynetrc>=1.3.1 (from earthaccess)
#   Using cached tinynetrc-1.3.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from earthaccess)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting bounded-pool-executor (from pqdm>=0.1->earthaccess)
#   Using cached bounded_pool_executor-0.0.3-py3-none-any.whl.metadata (2.7 kB)
# Collecting tqdm (from pqdm>=0.1->earthaccess)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting python-dateutil<3.0.0,>=2.8.2 (from python-cmr>=0.10.0->earthaccess)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.26->earthaccess)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests>=2.26->earthaccess)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.26->earthaccess)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.26->earthaccess)
#   Downloading certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Collecting aiobotocore<4.0.0,>=2.5.4 (from s3fs>=2025.2->earthaccess)
#   Using cached aiobotocore-3.1.1-py3-none-any.whl.metadata (26 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from s3fs>=2025.2->earthaccess)
#   Using cached aiohttp-3.13.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<4.0.0,>=2.5.4->s3fs>=2025.2->earthaccess)
#   Using cached aioitertools-0.13.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting botocore<1.42.31,>=1.41.0 (from aiobotocore<4.0.0,>=2.5.4->s3fs>=2025.2->earthaccess)
#   Using cached botocore-1.42.30-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<4.0.0,>=2.5.4->s3fs>=2025.2->earthaccess)
#   Using cached jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting multidict<7.0.0,>=6.0.0 (from aiobotocore<4.0.0,>=2.5.4->s3fs>=2025.2->earthaccess)
#   Using cached multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting wrapt<3.0.0,>=1.10.10 (from aiobotocore<4.0.0,>=2.5.4->s3fs>=2025.2->earthaccess)
#   Using cached wrapt-2.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Using cached frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Using cached propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess)
#   Using cached yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Collecting six>=1.5 (from python-dateutil<3.0.0,>=2.8.2->python-cmr>=0.10.0->earthaccess)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached earthaccess-0.16.0-py3-none-any.whl (71 kB)
# Using cached fsspec-2026.1.0-py3-none-any.whl (201 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached multimethod-2.0.2-py3-none-any.whl (9.6 kB)
# Using cached pqdm-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Using cached python_cmr-0.13.0-py3-none-any.whl (14 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 378.5 kB/s eta 0:00:00a 0:00:01
# Using cached s3fs-2026.1.0-py3-none-any.whl (30 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached tinynetrc-1.3.1-py2.py3-none-any.whl (3.9 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 268.0 kB/s eta 0:00:00a 0:00:01
# Using cached aiobotocore-3.1.1-py3-none-any.whl (87 kB)
# Using cached aiohttp-3.13.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
# Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 kB 967.3 kB/s eta 0:00:00a 0:00:01
# Downloading charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.5/153.5 kB 949.0 kB/s eta 0:00:00a 0:00:01
# Downloading idna-3.11-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 358.4 kB/s eta 0:00:00a 0:00:01
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 1.2 MB/s eta 0:00:00:00:01
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 963.1 kB/s eta 0:00:00a 0:00:01
# Using cached bounded_pool_executor-0.0.3-py3-none-any.whl (3.4 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aioitertools-0.13.0-py3-none-any.whl (24 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 362.2 kB/s eta 0:00:00a 0:00:01
# Using cached botocore-1.42.30-py3-none-any.whl (14.6 MB)
# Using cached frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
# Using cached jmespath-1.1.0-py3-none-any.whl (20 kB)
# Using cached multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
# Using cached propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (221 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached wrapt-2.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (121 kB)
# Using cached yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (377 kB)
# Installing collected packages: tinynetrc, bounded-pool-executor, wrapt, urllib3, typing-extensions, tqdm, tenacity, six, propcache, multimethod, multidict, jmespath, importlib-resources, idna, fsspec, frozenlist, charset_normalizer, certifi, attrs, aioitertools, aiohappyeyeballs, yarl, requests, python-dateutil, pqdm, aiosignal, python-cmr, botocore, aiohttp, aiobotocore, s3fs, earthaccess
# Successfully installed aiobotocore-3.1.1 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aioitertools-0.13.0 aiosignal-1.4.0 attrs-25.4.0 botocore-1.42.30 bounded-pool-executor-0.0.3 certifi-2026.1.4 charset_normalizer-3.4.4 earthaccess-0.16.0 frozenlist-1.8.0 fsspec-2026.1.0 idna-3.11 importlib-resources-6.5.2 jmespath-1.1.0 multidict-6.7.1 multimethod-2.0.2 pqdm-0.2.0 propcache-0.4.1 python-cmr-0.13.0 python-dateutil-2.9.0.post0 requests-2.32.5 s3fs-2026.1.0 six-1.17.0 tenacity-9.1.2 tinynetrc-1.3.1 tqdm-4.67.3 typing-extensions-4.15.0 urllib3-2.6.3 wrapt-2.1.1 yarl-1.22.0
# Installed to: /home/jcoldiron/.local/lib/python3.12/site-packages
# Now try: import earthaccess

# %%
import earthaccess
print("Success! earthaccess imported")
# Out:
# Success! earthaccess imported

# %%
import earthaccess
from pathlib import Path

# Authenticate with NASA Earthdata
# Will use credentials from ~/.netrc or prompt for login
auth = earthaccess.login()

# =============================================================================
# Configuration for Iowa 2023
# =============================================================================

# Year to download (just 2023 for this project)
year = 2023
temporal_range = (f"{year}-01-01", f"{year}-12-31")

# Iowa bounding box (west, south, east, north)
# Coordinates from Iowa state boundary
iowa_bbox = (-96.64, 40.38, -90.14, 43.50)

# Project paths - relative to notebook location
project_root = Path("../..").resolve()
local_path = project_root / "data" / "raw" / "NLDAS"
local_path.mkdir(parents=True, exist_ok=True)

print(f"Project root: {project_root}")
print(f"Download path: {local_path}")
print(f"Temporal range: {temporal_range}")
print(f"Bounding box (Iowa): {iowa_bbox}")

# =============================================================================
# Download NLDAS Monthly Precipitation Data
# =============================================================================

print(f"\nSearching NLDAS data for: {temporal_range[0]} to {temporal_range[1]}")

results = earthaccess.search_data(
    doi="10.5067/2DPKB5B5N14O",  # NLDAS Primary Forcing Monthly
    temporal=temporal_range,
    bounding_box=iowa_bbox
)

print(f"Found {len(results)} granules")

if results:
    downloaded_files = earthaccess.download(results, local_path=str(local_path))
    print(f"\nDownloaded {len(downloaded_files)} files to: {local_path}")
else:
    print("No data found for the specified parameters")

print("\nDownload complete!")
# Out:
# Project root: /home/jcoldiron/iowa-corn-project/code/SIF-Analysis
# Download path: /home/jcoldiron/iowa-corn-project/code/SIF-Analysis/data/raw/NLDAS
# Temporal range: ('2023-01-01', '2023-12-31')
# Bounding box (Iowa): (-96.64, 40.38, -90.14, 43.5)
#
# Searching NLDAS data for: 2023-01-01 to 2023-12-31
# Found 12 granules
# QUEUEING TASKS | :   0%|          | 0/12 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/12 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/12 [00:00<?, ?it/s]
# Downloaded 12 files to: /home/jcoldiron/iowa-corn-project/code/SIF-Analysis/data/raw/NLDAS
#
# Download complete!

# %%
"""
Process and Clip NLDAS Potential Evaporation Data to Iowa Boundary

This cell:
1. Loads each downloaded NetCDF file
2. Extracts the potential evaporation (PEVAP) variable
3. Clips to Iowa state boundary
4. Saves clipped files and computes monthly mean

PEVAP units: kg/m²/s (mass flux rate)
To convert to mm/day: multiply by 86400
"""

import os
import glob
import xarray as xr
import rioxarray as rxr
import geopandas as gpd
import pandas as pd
from pathlib import Path

# =============================================================================
# File Paths - Iowa Project
# =============================================================================

project_root = Path("../..").resolve()

# Input: Raw NLDAS data
input_folder = project_root / "data" / "raw" / "NLDAS"

# Output: Processed/clipped data
output_folder = project_root / "data" / "processed" / "NLDAS_Iowa"
output_folder.mkdir(parents=True, exist_ok=True)

# Iowa boundary - use the dissolved AOI we created
iowa_boundary = project_root / "data" / "aoi" / "iowa.geojson"

print(f"Input folder: {input_folder}")
print(f"Output folder: {output_folder}")
print(f"Iowa boundary: {iowa_boundary}")

# Verify files exist
nc_files = list(input_folder.glob("*.nc"))
print(f"\nFound {len(nc_files)} NetCDF files to process")

# =============================================================================
# Load Iowa Boundary
# =============================================================================

gdf = gpd.read_file(iowa_boundary)
print(f"Iowa boundary CRS: {gdf.crs}")

# =============================================================================
# Process Each NetCDF File - Extract PEVAP
# =============================================================================

datasets_2023 = []

for file in sorted(nc_files):
    try:
        # Open dataset
        ds = xr.open_dataset(file)
        
        # Extract POTENTIAL EVAPORATION variable
        data = ds["PEVAP"]
        
        # Set CRS for the data
        data = data.rio.write_crs("EPSG:4326")
        
        # Ensure shapefile is in same CRS
        gdf_projected = gdf.to_crs(data.rio.crs)
        
        # Clip to Iowa boundary
        clipped = data.rio.clip(gdf_projected.geometry, gdf_projected.crs, drop=True)
        
        # Store for averaging
        datasets_2023.append(clipped)
        
        # Save clipped file
        filename = file.stem + "_PEVAP_Iowa.nc"
        output_path = output_folder / filename
        clipped.to_netcdf(output_path)
        
        print(f"Processed: {file.name} -> {filename}")
        
    except Exception as e:
        print(f"Error processing {file.name}: {e}")

# =============================================================================
# Compute and Save Annual Mean PET
# =============================================================================

if datasets_2023:
    print(f"\nComputing annual mean PET from {len(datasets_2023)} months...")
    
    # Concatenate all months and compute mean
    mean_pet = xr.concat(datasets_2023, dim="time").mean(dim="time", keep_attrs=True)
    
    # Ensure correct orientation (north-up)
    if 'lat' in mean_pet.dims and mean_pet.lat[0] < mean_pet.lat[-1]:
        mean_pet = mean_pet.sortby('lat', ascending=False)
    
    # Save as GeoTIFF
    mean_output = output_folder / "PET_mean_2023_Iowa.tif"
    mean_pet.rio.to_raster(mean_output)
    print(f"Saved annual mean PET to: {mean_output}")
    
    # Also save in mm/day units for easier interpretation
    mean_pet_mm_day = mean_pet * 86400  # Convert kg/m²/s to mm/day
    mean_output_mm = output_folder / "PET_mean_2023_Iowa_mm_day.tif"
    mean_pet_mm_day.rio.to_raster(mean_output_mm)
    print(f"Saved annual mean PET (mm/day) to: {mean_output_mm}")
else:
    print("No data processed - check input files")

print("\nProcessing complete!")

# %%
"""
Visualize Mean Potential Evaporation for Iowa 2023
"""

import matplotlib.pyplot as plt

# Convert to mm/day for easier interpretation
mean_pet_mm_day = mean_pet * 86400

# Plot the annual mean PET
fig, ax = plt.subplots(figsize=(10, 8))

mean_pet_mm_day.plot(
    ax=ax,
    cmap='YlOrRd',
    cbar_kwargs={'label': 'Potential Evaporation (mm/day)'}
)

ax.set_title('NLDAS Mean Potential Evaporation (PET) - Iowa 2023', fontsize=14, fontweight='bold')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

plt.tight_layout()
plt.show()

# Print statistics
print(f"\nPotential Evaporation Statistics (Iowa 2023):")
print(f"  Min: {float(mean_pet_mm_day.min()):.2f} mm/day")
print(f"  Max: {float(mean_pet_mm_day.max()):.2f} mm/day")
print(f"  Mean: {float(mean_pet_mm_day.mean()):.2f} mm/day")
print(f"\nNote: Compare with ECOSTRESS ET to identify irrigation:")
print(f"  Where ET > PET → likely irrigated")
print(f"  Where ET < PET → water-stressed or rainfed")
